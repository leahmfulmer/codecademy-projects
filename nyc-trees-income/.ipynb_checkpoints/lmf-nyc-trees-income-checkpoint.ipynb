# %% [markdown]
# # NYC Tree Census and Income
# Codecademy Portfolio Project by Leah Fulmer ([Github](https://github.com/leahmfulmer), [Tableau](https://public.tableau.com/app/profile/leahmfulmer/vizzes))<br>
# With gratitude to David Belyaev ([Tableau](https://public.tableau.com/app/profile/david.belyaev/vizzes))

# %% [markdown]
# #### Project Objectives:
#
# * Explore a given data set.
# * Form questions for analysis.
# * Create several visualizations.
# * Combine visualizations in a Tableau Dashboard.
# * Present interactive visual dashboard through [Tableau Public](https://public.tableau.com/app/profile/leahmfulmer/viz/NYCTreesIncome_17195152146380/NYCTreesIncome).

# %% [markdown]
# #### Table of Contents :
# [Section 1: Loading and Examining the Data](#data)<br>
# [Section 2: Wrangling and Tidying the Data](#tidy)<br>
# [Section 3: Defining Questions for Analysis](#questions)<br>
# [Section 4: Transitioning to Tableau Public](#tableau)<br>

# %% [markdown]
# ### Section 1: Loading and Examining the Data <a id="data"></a>

# %%
# Import modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data: tree_census
# Data can be found here: https://github.com/Codecademy-Curriculum/Learn-Tableau-for-Data-Viz/tree/main/datasets
tree_census = pd.read_csv("./datasets/tree-census-NYC_2015.csv")

print("This dataset contains {} rows and {} columns. \n".format(tree_census.shape[0], tree_census.shape[1]))
print("The columns are called ...{}.".format(tree_census.columns))
# Out:
# This dataset contains 683788 rows and 16 columns.
#
# The columns are called ...Index(['Unnamed: 0', 'tree_id', 'tree_dbh', 'stump_diam', 'status', 'health',
#        'spc_latin', 'spc_common', 'address', 'zipcode', 'borocode', 'boroname',
#        'nta_name', 'state', 'Latitude', 'longitude'],
#       dtype='object').

# %%
# Examine data: tree_census
tree_census.head(50)
# Out:
#     Unnamed: 0  tree_id  tree_dbh  stump_diam status health  \
# 0            0   180683         3           0  Alive   Fair
# 1            1   200540        21           0  Alive   Fair
# 2            2   204026         3           0  Alive   Good
# 3            3   204337        10           0  Alive   Good
# 4            4   189565        21           0  Alive   Good
# 5            5   190422        11           0  Alive   Good
# 6            6   190426        11           0  Alive   Good
# 7            7   208649         9           0  Alive   Good
# 8            8   209610         6           0  Alive   Good
# 9            9   192755        21           0  Alive   Fair
# 10          10   203719        11           0  Alive   Good
# 11          11   203726         8           0  Alive   Poor
# 12          12   195202        13           0  Alive   Fair
# 13          13   189465        22           0  Alive   Good
# 14          14   192998        30           0  Alive   Fair
# 15          15   189834        12           0  Alive   Good
# 16          16   204208         2           0  Alive   Fair
# 17          17   161339        14           0  Alive   Good
# 18          18   187311        14           0  Alive   Fair
# 19          19   208201        10           0  Alive   Good
# 20          20   193093        11           0  Alive   Good
# 21          21   193310        14           0  Alive   Good
# 22          22   199760         4           0  Alive   Fair
# 23          23   204325         9           0  Alive   Good
# 24          24   189700         2           0  Alive   Good
# 25          25   205044         5           0  Alive   Good
# 26          26   192942        33           0  Alive   Good
# 27          27   195265        19           0  Alive   Good
# 28          28   201555         9           0  Alive   Good
# 29          29   208407         9           0  Alive   Good
# 30          30   189164         7           0  Alive   Good
# 31          31   184375         3           0  Alive   Good
# 32          32   187056         7           0  Alive   Good
# 33          33   187058         5           0  Alive   Good
# 34          34   178659         4           0  Alive   Good
# 35          35   190423        12           0  Alive   Good
# 36          36   190425        13           0  Alive   Good
# 37          37   204202        12           0  Alive   Fair
# 38          38   201494        24           0  Alive   Good
# 39          39   208346        20           0  Alive   Good
# 40          40   181710        13           0  Alive   Good
# 41          41   178382        12           0  Alive   Fair
# 42          42   193690        36           0  Alive   Good
# 43          43   196089        29           0  Alive   Good
# 44          44   191988         6           0  Alive   Good
# 45          45   203720         9           0  Alive   Good
# 46          46   189339        18           0  Alive   Good
# 47          47   208230        13           0  Alive   Fair
# 48          48   204413        13           0  Alive   Good
# 49          49   161193         9           0  Alive   Good
#
#                              spc_latin        spc_common  \
# 0                          Acer rubrum         red maple
# 1                    Quercus palustris           pin oak
# 2   Gleditsia triacanthos var. inermis       honeylocust
# 3   Gleditsia triacanthos var. inermis       honeylocust
# 4                      Tilia americana   American linden
# 5   Gleditsia triacanthos var. inermis       honeylocust
# 6   Gleditsia triacanthos var. inermis       honeylocust
# 7                      Tilia americana   American linden
# 8   Gleditsia triacanthos var. inermis       honeylocust
# 9                Platanus x acerifolia  London planetree
# 10               Platanus x acerifolia  London planetree
# 11               Platanus x acerifolia  London planetree
# 12               Platanus x acerifolia  London planetree
# 13               Platanus x acerifolia  London planetree
# 14               Platanus x acerifolia  London planetree
# 15  Gleditsia triacanthos var. inermis       honeylocust
# 16                       Ginkgo biloba            ginkgo
# 17  Gleditsia triacanthos var. inermis       honeylocust
# 18  Gleditsia triacanthos var. inermis       honeylocust
# 19                       Ginkgo biloba            ginkgo
# 20  Gleditsia triacanthos var. inermis       honeylocust
# 21  Gleditsia triacanthos var. inermis       honeylocust
# 22                     Quercus phellos        willow oak
# 23                 Acer pseudoplatanus    sycamore maple
# 24                     Quercus phellos        willow oak
# 25                        Acer ginnala        Amur maple
# 26               Platanus x acerifolia  London planetree
# 27               Platanus x acerifolia  London planetree
# 28  Gleditsia triacanthos var. inermis       honeylocust
# 29  Gleditsia triacanthos var. inermis       honeylocust
# 30  Gleditsia triacanthos var. inermis       honeylocust
# 31  Gleditsia triacanthos var. inermis       honeylocust
# 32  Gleditsia triacanthos var. inermis       honeylocust
# 33  Gleditsia triacanthos var. inermis       honeylocust
# 34  Gleditsia triacanthos var. inermis       honeylocust
# 35  Gleditsia triacanthos var. inermis       honeylocust
# 36  Gleditsia triacanthos var. inermis       honeylocust
# 37               Platanus x acerifolia  London planetree
# 38               Platanus x acerifolia  London planetree
# 39               Platanus x acerifolia  London planetree
# 40                     Quercus phellos        willow oak
# 41               Platanus x acerifolia  London planetree
# 42               Platanus x acerifolia  London planetree
# 43               Platanus x acerifolia  London planetree
# 44                     Quercus phellos        willow oak
# 45               Platanus x acerifolia  London planetree
# 46               Platanus x acerifolia  London planetree
# 47               Platanus x acerifolia  London planetree
# 48                     Quercus phellos        willow oak
# 49                     Quercus phellos        willow oak
#
#                     address  zipcode  borocode       boroname  \
# 0         108-005 70 AVENUE    11375         4         Queens
# 1          147-074 7 AVENUE    11357         4         Queens
# 2         390 MORGAN AVENUE    11211         3       Brooklyn
# 3         1027 GRAND STREET    11211         3       Brooklyn
# 4              603 6 STREET    11215         3       Brooklyn
# 5         8 COLUMBUS AVENUE    10023         1      Manhattan
# 6        120 WEST 60 STREET    10023         1      Manhattan
# 7        311 WEST 50 STREET    10019         1      Manhattan
# 8          65 JEROME AVENUE    10305         5  Staten Island
# 9              638 AVENUE Z    11223         3       Brooklyn
# 10         20-025 24 STREET    11105         4         Queens
# 11         20-055 24 STREET    11105         4         Queens
# 12         35 FENWAY CIRCLE    10308         5  Staten Island
# 13       100 WAVERLY AVENUE    11205         3       Brooklyn
# 14        2126 UNION STREET    11212         3       Brooklyn
# 15        449 MYRTLE AVENUE    11205         3       Brooklyn
# 16           8797 25 AVENUE    11214         3       Brooklyn
# 17       1601 CHURCH AVENUE    11226         3       Brooklyn
# 18         55-026 96 STREET    11373         4         Queens
# 19       206 CARLTON AVENUE    11205         3       Brooklyn
# 20      367 PROSPECT AVENUE    11215         3       Brooklyn
# 21       170 EAST 75 STREET    10021         1      Manhattan
# 22            2163 BROADWAY    10024         1      Manhattan
# 23        301 THOMAS STREET    10306         5  Staten Island
# 24              26 8 AVENUE    11217         3       Brooklyn
# 25        134 BAY 40 STREET    11214         3       Brooklyn
# 26        84-036 127 STREET    11415         4         Queens
# 27             401 AVENUE O    11230         3       Brooklyn
# 28        71 STANTON STREET    10002         1      Manhattan
# 29      1817 DE KALB AVENUE    11385         4         Queens
# 30             456 5 AVENUE    11215         3       Brooklyn
# 31  2022 LA FONTAINE AVENUE    10457         2          Bronx
# 32            1880 BROADWAY    10023         1      Manhattan
# 33         1 WEST 62 STREET    10023         1      Manhattan
# 34       434 RARITAN AVENUE    10305         5  Staten Island
# 35       120 WEST 60 STREET    10023         1      Manhattan
# 36       120 WEST 60 STREET    10023         1      Manhattan
# 37        328 THOMAS STREET    10306         5  Staten Island
# 38          6 ALLISON PLACE    10306         5  Staten Island
# 39      418 COLUMBUS AVENUE    10024         1      Manhattan
# 40      267 WEST END AVENUE    11235         3       Brooklyn
# 41       520 EAST 20 STREET    10009         1      Manhattan
# 42           6018 24 AVENUE    11230         3       Brooklyn
# 43        84-037 124 STREET    11415         4         Queens
# 44   73 WEST HOUSTON STREET    10012         1      Manhattan
# 45         20-025 24 STREET    11105         4         Queens
# 46           79 HALL STREET    11205         3       Brooklyn
# 47         1 WEST 81 STREET    10024         1      Manhattan
# 48       2435 HARWAY AVENUE    11214         3       Brooklyn
# 49         86 BOGOTA STREET    10314         5  Staten Island
#
#                                              nta_name     state   Latitude  \
# 0                                        Forest Hills  New York  40.723092
# 1                                          Whitestone  New York  40.794111
# 2                                   East Williamsburg  New York  40.717581
# 3                                   East Williamsburg  New York  40.713537
# 4                                  Park Slope-Gowanus  New York  40.666778
# 5                                      Lincoln Square  New York  40.770046
# 6                                      Lincoln Square  New York  40.770210
# 7                                             Clinton  New York  40.762724
# 8                     Grasmere-Arrochar-Ft. Wadsworth  New York  40.596579
# 9                                           Gravesend  New York  40.586357
# 10                                           Steinway  New York  40.782428
# 11                                           Steinway  New York  40.781735
# 12                                        Great Kills  New York  40.557103
# 13                                       Clinton Hill  New York  40.694733
# 14                                        Brownsville  New York  40.664317
# 15                                       Clinton Hill  New York  40.693314
# 16                                   Bensonhurst East  New York  40.593788
# 17                                           Flatbush  New York  40.648788
# 18                                             Corona  New York  40.737646
# 19                                        Fort Greene  New York  40.691499
# 20                                 Park Slope-Gowanus  New York  40.661239
# 21                      Upper East Side-Carnegie Hill  New York  40.772171
# 22                                    Upper West Side  New York  40.782087
# 23                              Oakwood-Oakwood Beach  New York  40.568821
# 24                                 Park Slope-Gowanus  New York  40.674839
# 25                                   Bensonhurst East  New York  40.594936
# 26                                        Kew Gardens  New York  40.706534
# 27                                Ocean Parkway South  New York  40.611905
# 28                                          Chinatown  New York  40.721807
# 29                                          Ridgewood  New York  40.708040
# 30                                 Park Slope-Gowanus  New York  40.668826
# 31                                       East Tremont  New York  40.847947
# 32                                     Lincoln Square  New York  40.770396
# 33                                     Lincoln Square  New York  40.770227
# 34                  Old Town-Dongan Hills-South Beach  New York  40.588107
# 35                                     Lincoln Square  New York  40.770087
# 36                                     Lincoln Square  New York  40.770181
# 37                              Oakwood-Oakwood Beach  New York  40.568825
# 38                             New Dorp-Midland Beach  New York  40.578074
# 39                                    Upper West Side  New York  40.782587
# 40     Sheepshead Bay-Gerritsen Beach-Manhattan Beach  New York  40.575205
# 41                     Stuyvesant Town-Cooper Village  New York  40.733716
# 42                                Ocean Parkway South  New York  40.613663
# 43                                        Kew Gardens  New York  40.704047
# 44             SoHo-TriBeCa-Civic Center-Little Italy  New York  40.726640
# 45                                           Steinway  New York  40.782340
# 46                                       Clinton Hill  New York  40.695281
# 47                                    Upper West Side  New York  40.782181
# 48                                   Bensonhurst East  New York  40.593932
# 49  Todt Hill-Emerson Hill-Heartland Village-Light...  New York  40.585850
#
#     longitude
# 0  -73.844215
# 1  -73.818679
# 2  -73.936608
# 3  -73.934456
# 4  -73.975979
# 5  -73.984950
# 6  -73.985338
# 7  -73.987297
# 8  -74.076255
# 9  -73.969744
# 10 -73.911171
# 11 -73.912020
# 12 -74.162670
# 13 -73.968211
# 14 -73.921130
# 15 -73.967601
# 16 -73.991597
# 17 -73.964524
# 18 -73.865300
# 19 -73.972588
# 20 -73.985889
# 21 -73.960456
# 22 -73.980964
# 23 -74.138563
# 24 -73.972184
# 25 -73.989171
# 26 -73.824992
# 27 -73.970427
# 28 -73.989830
# 29 -73.915497
# 30 -73.986703
# 31 -73.893382
# 32 -73.981627
# 33 -73.981218
# 34 -74.086678
# 35 -73.985048
# 36 -73.985269
# 37 -74.139062
# 38 -74.114746
# 39 -73.974840
# 40 -73.952467
# 41 -73.977058
# 42 -73.974530
# 43 -73.827680
# 44 -73.999368
# 45 -73.911279
# 46 -73.966380
# 47 -73.972390
# 48 -73.993801
# 49 -74.148040

# %%
# Load data: income
income = pd.read_csv("./datasets/income-NYC_2015.csv")

print("This dataset contains {} rows and {} columns. \n".format(income.shape[0], income.shape[1]))
print("The columns are called ...{}.".format(income.columns))
# Out:
# This dataset contains 218 rows and 8 columns.
#
# The columns are called ...Index(['GEO_ID', 'zipcode', 'HouseholdsEstimateTotal',
#        'HouseholdsMargin of ErrorTotal',
#        'HouseholdsEstimateMedian income (dollars)',
#        'HouseholdsMargin of ErrorMedian income (dollars)',
#        'HouseholdsEstimateMean income (dollars)',
#        'HouseholdsMargin of ErrorMean income (dollars)'],
#       dtype='object').

# %%
# Examine data: income
income.head()
# Out:
#            GEO_ID  zipcode  HouseholdsEstimateTotal  \
# 0  8600000US10451    10451                    18140
# 1  8600000US10452    10452                    25432
# 2  8600000US10453    10453                    26802
# 3  8600000US10454    10454                    12790
# 4  8600000US10455    10455                    14023
#
#    HouseholdsMargin of ErrorTotal HouseholdsEstimateMedian income (dollars)  \
# 0                             405                                     26048
# 1                             368                                     24790
# 2                             409                                     23095
# 3                             247                                     20210
# 4                             329                                     23253
#
#    HouseholdsMargin of ErrorMedian income (dollars)  \
# 0                                            2140.0
# 1                                            1337.0
# 2                                            1605.0
# 3                                            1930.0
# 4                                            1598.0
#
#    HouseholdsEstimateMean income (dollars)  \
# 0                                  40836.0
# 1                                  36083.0
# 2                                  33354.0
# 3                                  31533.0
# 4                                  32854.0
#
#    HouseholdsMargin of ErrorMean income (dollars)
# 0                                          3424.0
# 1                                          1578.0
# 2                                          1416.0
# 3                                          2272.0
# 4                                          2127.0

# %% [markdown]
# ### Section 2: Wrangling and Tidying the Data<a id="tidy"></a>

# %% [markdown]
# After mapping the boroughs with Tableau Public, I noticed that some datapoints were labeled incorrectly. The zipcode 11234 is in Brooklyn, <br>but Tableau said that it was in Queens. This led to misrepresentations in the distribution of trees across boroughs. Let's correct this.

# %%
# What is the error?

zip_11234 = tree_census[tree_census.zipcode == 11234]
zip_11234.boroname.unique()
zip_11234.borocode.unique()
# Out:
# array([3, 4])

# %%
# Which points are labelled incorrectly?

incorrect_label = tree_census[(tree_census.zipcode == 11234) & (tree_census.boroname == 'Queens')]
incorrect_label.head(50)
# Out:
#         Unnamed: 0  tree_id  tree_dbh  stump_diam status health  \
# 428387      428387   654303        11           0  Alive   Fair
# 429222      429222   654305         7           0  Alive   Good
# 429721      429721   654307         5           0  Alive   Fair
# 430241      430241   654309        48           0  Alive   Fair
# 430399      430399   654304         9           0  Alive   Good
# 432730      432730   654306        23           0  Alive   Good
# 432731      432731   654308        57           0  Alive   Good
#
#                     spc_latin        spc_common               address  \
# 428387  Platanus x acerifolia  London planetree  5031 FLATBUSH AVENUE
# 429222                 Prunus            cherry  5031 FLATBUSH AVENUE
# 429721                 Prunus            cherry  5031 FLATBUSH AVENUE
# 430241                  Morus          mulberry  5031 FLATBUSH AVENUE
# 430399                 Prunus            cherry  5031 FLATBUSH AVENUE
# 432730                  Morus          mulberry  5031 FLATBUSH AVENUE
# 432731                  Morus          mulberry  5031 FLATBUSH AVENUE
#
#         zipcode  borocode boroname  \
# 428387    11234         4   Queens
# 429222    11234         4   Queens
# 429721    11234         4   Queens
# 430241    11234         4   Queens
# 430399    11234         4   Queens
# 432730    11234         4   Queens
# 432731    11234         4   Queens
#
#                                               nta_name     state   Latitude  \
# 428387  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582074
# 429222  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582407
# 429721  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582577
# 430241  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582633
# 430399  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582130
# 432730  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582498
# 432731  Georgetown-Marine Park-Bergen Beach-Mill Basin  New York  40.582613
#
#         longitude
# 428387 -73.891625
# 429222 -73.891952
# 429721 -73.892141
# 430241 -73.892204
# 430399 -73.891643
# 432730 -73.892054
# 432731 -73.892182

# %% [markdown]
# It looks like only seven trees have an incorrect label for `boroname`. This is easy to edit individually.

# %%
# Edit borough for individual trees

tree_census.loc[428387, 'boroname'] = 'Brooklyn'
tree_census.loc[428387, 'borocode'] = 3
tree_census.loc[429222, 'boroname'] = 'Brooklyn'
tree_census.loc[429222, 'borocode'] = 3
tree_census.loc[429721, 'boroname'] = 'Brooklyn'
tree_census.loc[429721, 'borocode'] = 3
tree_census.loc[430241, 'boroname'] = 'Brooklyn'
tree_census.loc[430241, 'borocode'] = 3
tree_census.loc[430399, 'boroname'] = 'Brooklyn'
tree_census.loc[430399, 'borocode'] = 3
tree_census.loc[432730, 'boroname'] = 'Brooklyn'
tree_census.loc[432730, 'borocode'] = 3
tree_census.loc[432731, 'boroname'] = 'Brooklyn'
tree_census.loc[432731, 'borocode'] = 3

# %%
# Check that Brooklyn is the only borough associated with zipcode 11234

check = tree_census[(tree_census.zipcode == 11234)]
check.boroname.unique()
check.borocode.unique()
# Out:
# array([3])

# %%
# Filter out unhealthy trees to reduce size of dataset

tree_census = tree_census[(tree_census.health == 'Good')]

# %%
# Save data

tree_census.to_csv("datasets/tree-census-NYC-2015-short.csv")

# %% [markdown]
# ### Section 3: Defining Questions for Analysis<a id="questions"></a>

# %% [markdown]
# * Is there a correlation between household income and tree characteristics (e.g., size, health)?
#     * *This is our driving question. It's why we're bringing these datasets together in the first place.*
# * Which borough has the most trees?
# * Where in New York City do we find the highest and lowest incomes?
#     * Is there variation within a borough, or is there income clustering?
#     * Do all wealthy households live in the same borough?
# * Where in New York City do we find the largest trees? The smallest?

# %% [markdown]
# ### Section 4: Transitioning to Tableau Public<a id="tableau"></a>

# %% [markdown]
# All of these questions can be explored visually. It's time to take ourselves over to Tableau Public for some [*interactive visualizations!*](https://public.tableau.com/app/profile/leahmfulmer/viz/NYCTreesIncome_17195152146380/NYCTreesIncome?publish=yes)
